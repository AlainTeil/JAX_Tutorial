# %% [markdown]
# # Lesson 01: Why JAX for Deep Learning
#
#             **Phase:** Foundations
#             **Script:** `lessons/lesson_01_why_jax.py`
#             **Exercise:** `exercise_accuracy_from_logits`
#             **Reference solution:** `solutions.lesson_01_solution.accuracy_from_logits`

# %% [markdown]
# ## What This Lesson Teaches
# - Train a tiny logistic model with pure functions and immutable parameter updates.
# - Connect NumPy-shaped array code to JAX transformations and autodiff.
# - Read a before/after loss check as evidence that a functional update worked.
#
# ## Mental Model
# JAX code is ordinary array code until a transformation stages it. Keep model state explicit so `grad`, `jit`, and tests see the same inputs.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_01_why_jax as lesson
import solutions.lesson_01_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
x, y = lesson.make_toy_batch()
params = lesson.init_logreg_params(x.shape[1])
initial_loss = lesson.loss_fn(params, x, y)
for _ in range(30):
    params, _ = lesson.gd_step(params, x, y, lr=0.2)
final_loss = lesson.loss_fn(params, x, y)
logits = lesson.predict_logits(params, x)
print(f'shape={x.shape}, initial_loss={float(initial_loss):.4f}, final_loss={float(final_loss):.4f}')
print('exercise_accuracy=', float(solution.accuracy_from_logits(logits, y)))
# Out:
# shape=(4, 2), initial_loss=0.6931, final_loss=0.5317
# exercise_accuracy= 0.75

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_accuracy_from_logits`. Implement accuracy from binary logits by thresholding probabilities and averaging correct predictions.
#
# Hint: Use `jax.nn.sigmoid(logits) >= 0.5`, compare to labels, cast to float, then take the mean.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_accuracy_from_logits')
print('reference:', 'solutions.lesson_01_solution.accuracy_from_logits')
print('status: ready for student implementation')
# Out:
# exercise: exercise_accuracy_from_logits
# reference: solutions.lesson_01_solution.accuracy_from_logits
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - The final loss is lower than the initial loss after repeated gradient steps.
# - Predictions have the same leading dimension as the labels.
# - The exercise check reports an accuracy between 0 and 1.

# %% [markdown]
# ## Common Mistakes
# - Treating parameter dictionaries like hidden mutable model state.
# - Interpreting a decreasing loss without checking shapes, labels, and logits.
#
# ## Extension
# Try changing the learning rate to see when the simple training loop becomes unstable.
