# %% [markdown]
# # Lesson 02: JAX Arrays and Core Operations
#
#             **Phase:** Foundations
#             **Script:** `lessons/lesson_02_arrays.py`
#             **Exercise:** `exercise_row_normalize`
#             **Reference solution:** `solutions.lesson_02_solution.row_normalize`

# %% [markdown]
# ## What This Lesson Teaches
# - Create and inspect JAX arrays with predictable shapes and dtypes.
# - Use slicing, broadcasting, indexed updates, and matrix multiplication idiomatically.
# - Normalize rows without mutating the input array.
#
# ## Mental Model
# JAX arrays are immutable values. Operations return new arrays, which is what makes transformations and device placement predictable.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_02_arrays as lesson
import solutions.lesson_02_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
arrays = lesson.create_core_arrays()
vector, matrix = arrays['vector'], arrays['matrix']
updated = lesson.immutable_set(vector, 1, 99.0)
normalized = solution.row_normalize(jnp.array([[1.0, 1.0], [2.0, 6.0]], dtype=jnp.float32))
print('vector=', vector.tolist(), 'updated=', updated.tolist())
print('matrix_shape=', matrix.shape, 'row_sums=', jnp.sum(normalized, axis=1).tolist())
# Out:
# vector= [1.0, 2.0, 3.0] updated= [1.0, 99.0, 3.0]
# matrix_shape= (3, 3) row_sums= [1.0, 1.0]

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_row_normalize`. Implement row normalization so each row sums to one while preserving shape.
#
# Hint: Compute row sums with `keepdims=True` and divide with a small zero-safety guard if needed.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_row_normalize')
print('reference:', 'solutions.lesson_02_solution.row_normalize')
print('status: ready for student implementation')
# Out:
# exercise: exercise_row_normalize
# reference: solutions.lesson_02_solution.row_normalize
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Immutable updates leave the original input unchanged.
# - Broadcasted operations have the expected matrix shape.
# - Normalized row sums are close to one.

# %% [markdown]
# ## Common Mistakes
# - Expecting `x[index] = value` style mutation to work inside transformed code.
# - Letting broadcasting hide an unintended rank or axis mismatch.
#
# ## Extension
# Add a zero row and decide how your normalization should handle it.
