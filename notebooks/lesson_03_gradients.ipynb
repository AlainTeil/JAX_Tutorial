# %% [markdown]
# # Lesson 03: Automatic Differentiation with grad
#
#             **Phase:** Foundations
#             **Script:** `lessons/lesson_03_gradients.py`
#             **Exercise:** `exercise_mae_grad`
#             **Reference solution:** `solutions.lesson_03_solution.mae_grads`

# %% [markdown]
# ## What This Lesson Teaches
# - Differentiate scalar-valued functions with `jax.grad`.
# - Compute parameter gradients for a linear model loss.
# - Inspect Jacobians when a function returns vectors instead of scalars.
#
# ## Mental Model
# Reverse-mode autodiff needs a scalar objective. When outputs are structured, choose the derivative object deliberately: gradient, Jacobian, or Hessian.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_03_gradients as lesson
import solutions.lesson_03_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
params = {'w': jnp.array([1.0, -1.0]), 'b': jnp.array(0.1)}
x = jnp.array([[1.0, 2.0], [2.0, -1.0]], dtype=jnp.float32)
y = jnp.array([0.0, 1.0], dtype=jnp.float32)
_, grads = lesson.mse_grads(params, x, y)
_, mae_grads = solution.mae_grads(params, x, y)
print('scalar_grad_at_3=', float(lesson.scalar_grad(3.0)))
print('mse_grad_shapes=', {k: v.shape for k, v in grads.items()})
print('mae_grad_w=', mae_grads['w'].round(4).tolist())
# Out:
# scalar_grad_at_3= 29.0
# mse_grad_shapes= {'b': (), 'w': (2,)}
# mae_grad_w= [0.75, -0.75]

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_mae_grad`. Implement MAE loss gradients for a linear model.
#
# Hint: Define an MAE scalar loss first, then pass it to `jax.grad` with respect to the parameter tree.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_mae_grad')
print('reference:', 'solutions.lesson_03_solution.mae_grads')
print('status: ready for student implementation')
# Out:
# exercise: exercise_mae_grad
# reference: solutions.lesson_03_solution.mae_grads
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - The scalar derivative matches the analytic slope at the demo point.
# - Gradient pytrees match the parameter pytree structure.
# - The MAE gradient exposes the sign-based behavior of absolute error.

# %% [markdown]
# ## Common Mistakes
# - Calling `grad` on a vector-valued function and expecting a full Jacobian.
# - Differentiating through integer or boolean values instead of floating arrays.
#
# ## Extension
# Compare MSE and MAE gradients near zero residuals.
