# %% [markdown]
# # Lesson 04: Compilation with jit
#
#             **Phase:** Foundations
#             **Script:** `lessons/lesson_04_jit.py`
#             **Exercise:** `exercise_jitted_relu`
#             **Reference solution:** `solutions.lesson_04_solution._relu`

# %% [markdown]
# ## What This Lesson Teaches
# - Compile pure numerical functions with `jax.jit`.
# - Separate array inputs from static Python choices that affect tracing.
# - Run a jitted training step that returns updated parameters and loss.
#
# ## Mental Model
# `jit` traces Python once for a shape/dtype/static-argument signature, then reuses compiled device code for matching calls.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_04_jit as lesson
import solutions.lesson_04_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
params = {'w': jnp.array([[1.0], [-1.0]]), 'b': jnp.array([0.0])}
x = jnp.array([[1.0, 2.0], [2.0, 1.0]], dtype=jnp.float32)
y = jnp.array([[0.0], [1.0]], dtype=jnp.float32)
new_params, loss = lesson.train_step(params, x, y, lr=0.1)
relu_values = solution._relu(jnp.array([-2.0, 0.0, 3.0]))
print('loss=', float(loss), 'updated_keys=', sorted(new_params))
print('powered_sum=', float(lesson.powered_sum(jnp.array([2.0, 3.0]), 2)))
print('relu=', relu_values.tolist())
# Out:
# loss= 0.5 updated_keys= ['b', 'w']
# powered_sum= 13.0
# relu= [0.0, 0.0, 3.0]

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_jitted_relu`. Implement a jitted ReLU and confirm it preserves shape while clipping negatives to zero.
#
# Hint: Write a small pure function around `jnp.maximum(x, 0)` and wrap it with `jax.jit`.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_jitted_relu')
print('reference:', 'solutions.lesson_04_solution._relu')
print('status: ready for student implementation')
# Out:
# exercise: exercise_jitted_relu
# reference: solutions.lesson_04_solution._relu
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - The jitted train step returns the same tree structure as the input parameters.
# - Static choices such as `power` are explicit at the call boundary.
# - The ReLU exercise output has no negative values.

# %% [markdown]
# ## Common Mistakes
# - Changing Python control decisions inside a jitted function without marking them static.
# - Expecting print/debug side effects to behave like eager Python during compilation.
#
# ## Extension
# Use `jax.make_jaxpr` on a tiny function before and after adding a Python branch.
