# %% [markdown]
# # Lesson 05: Vectorization with vmap
#
#             **Phase:** Transform Patterns
#             **Script:** `lessons/lesson_05_vmap.py`
#             **Exercise:** `exercise_batch_cosine_similarity`
#             **Reference solution:** `solutions.lesson_05_solution.batch_cosine_similarity`

# %% [markdown]
# ## What This Lesson Teaches
# - Lift a single-example function to batched inputs with `jax.vmap`.
# - Control mapped axes for pairwise operations.
# - Compare loop-style batching with transformation-style batching.
#
# ## Mental Model
# `vmap` adds a batch axis to a function contract. The inner function should still describe one example clearly.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_05_vmap as lesson
import solutions.lesson_05_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
batch = jnp.array([[1.0, 2.0], [3.0, 4.0]], dtype=jnp.float32)
loop = lesson.batch_squared_l2_loop(batch)
mapped = lesson.batch_squared_l2_vmap(batch)
cosine = solution.batch_cosine_similarity(batch, batch)
print('loop_vs_vmap=', jnp.allclose(loop, mapped).item(), loop.tolist())
print('cosine_self=', cosine.round(4).tolist())
# Out:
# loop_vs_vmap= True [5.0, 25.0]
# cosine_self= [1.0, 1.0]

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_batch_cosine_similarity`. Implement batched cosine similarity for aligned batches of vectors.
#
# Hint: Normalize each row by its L2 norm, multiply aligned rows, then sum over the feature axis.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_batch_cosine_similarity')
print('reference:', 'solutions.lesson_05_solution.batch_cosine_similarity')
print('status: ready for student implementation')
# Out:
# exercise: exercise_batch_cosine_similarity
# reference: solutions.lesson_05_solution.batch_cosine_similarity
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Loop and `vmap` L2 computations agree numerically.
# - Batched linear output keeps the batch dimension first.
# - Cosine similarity returns one score per paired example.

# %% [markdown]
# ## Common Mistakes
# - Mapping over the wrong axis and silently comparing unrelated examples.
# - Writing a Python loop first and forgetting the simpler single-example function.
#
# ## Extension
# Nest `vmap` to build a full pairwise similarity matrix.
