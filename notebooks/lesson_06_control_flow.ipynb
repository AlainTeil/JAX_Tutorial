# %% [markdown]
# # Lesson 06: JAX Control Flow
#
#             **Phase:** Transform Patterns
#             **Script:** `lessons/lesson_06_control_flow.py`
#             **Exercise:** `exercise_weighted_cumsum`
#             **Reference solution:** `solutions.lesson_06_solution.weighted_cumsum`

# %% [markdown]
# ## What This Lesson Teaches
# - Use `lax.cond` for data-dependent branches.
# - Use `lax.scan` for loop-carried state over sequences.
# - Recognize when Python control flow should become JAX control flow.
#
# ## Mental Model
# Transformed JAX code needs control flow that can be represented in the traced program rather than decided by Python at trace time.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_06_control_flow as lesson
import solutions.lesson_06_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
xs = jnp.array([1.0, 2.0, 3.0], dtype=jnp.float32)
print('safe_inverse=', [float(lesson.safe_inverse(v)) for v in (0.0, 2.0)])
print('scan_sum=', lesson.cumulative_sum_scan(xs).tolist())
print('weighted=', solution.weighted_cumsum(xs, alpha=0.5).round(4).tolist())
# Out:
# safe_inverse= [0.0, 0.5]
# scan_sum= [1.0, 3.0, 6.0]
# weighted= [1.0, 2.5, 4.25]

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_weighted_cumsum`. Implement a weighted cumulative sum with `lax.scan`.
#
# Hint: Carry the running value and emit each updated carry as the scan output.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_weighted_cumsum')
print('reference:', 'solutions.lesson_06_solution.weighted_cumsum')
print('status: ready for student implementation')
# Out:
# exercise: exercise_weighted_cumsum
# reference: solutions.lesson_06_solution.weighted_cumsum
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Safe inverse avoids division blowups around zero.
# - Scan cumulative sums match the intuitive running total.
# - Weighted cumulative sums preserve sequence length.

# %% [markdown]
# ## Common Mistakes
# - Branching on a traced array with a Python `if`.
# - Using a Python loop for sequence state that should compose with `jit` or gradients.
#
# ## Extension
# Rewrite the scan as an explicit Python loop and compare where each version can be jitted.
