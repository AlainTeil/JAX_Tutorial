# %% [markdown]
# # Lesson 07: Random Numbers and PRNG Keys
#
#             **Phase:** Transform Patterns
#             **Script:** `lessons/lesson_07_randomness.py`
#             **Exercise:** `exercise_gaussian_stats`
#             **Reference solution:** `solutions.lesson_07_solution.gaussian_stats`

# %% [markdown]
# ## What This Lesson Teaches
# - Create, split, and pass explicit PRNG keys.
# - Sample deterministic random arrays for tests and demos.
# - Apply dropout without hidden global RNG state.
#
# ## Mental Model
# A JAX key is an explicit input, not a mutable global generator. Splitting keys creates independent streams you can pass through pure functions.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_07_randomness as lesson
import solutions.lesson_07_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
key = lesson.make_key(0)
k1, k2, _ = lesson.split_three(key)
sample = lesson.sample_normal(k1, (3,))
dropped = lesson.dropout(k2, jnp.ones((6,)), keep_prob=0.5)
mean, std = solution.gaussian_stats(lesson.make_key(1), 1000)
print('sample=', sample.round(4).tolist())
print('dropout_shape=', dropped.shape, 'stats=', (round(float(mean), 3), round(float(std), 3)))
# Out:
# sample= [1.003999948501587, -0.9062999486923218, -0.748199999332428]
# dropout_shape= (6,) stats= (-0.028, 1.013)

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_gaussian_stats`. Sample `n` standard normal values and return their empirical mean and standard deviation.
#
# Hint: Use one key once, then compute `jnp.mean` and `jnp.std` over the sample.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_gaussian_stats')
print('reference:', 'solutions.lesson_07_solution.gaussian_stats')
print('status: ready for student implementation')
# Out:
# exercise: exercise_gaussian_stats
# reference: solutions.lesson_07_solution.gaussian_stats
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Splitting one key yields reproducible but distinct samples.
# - Dropout preserves shape and scales kept activations.
# - Gaussian summary statistics are near the expected mean and scale.

# %% [markdown]
# ## Common Mistakes
# - Reusing the same key and mistaking repeated samples for randomness.
# - Hiding key creation inside model code where tests cannot control it.
#
# ## Extension
# Thread a key through two stochastic operations without reusing it.
