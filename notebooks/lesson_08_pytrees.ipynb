# %% [markdown]
# # Lesson 08: Pytrees Fundamentals
#
#             **Phase:** Transform Patterns
#             **Script:** `lessons/lesson_08_pytrees.py`
#             **Exercise:** `exercise_count_parameters`
#             **Reference solution:** `solutions.lesson_08_solution.count_parameters`

# %% [markdown]
# ## What This Lesson Teaches
# - Treat nested parameter containers as first-class JAX values.
# - Map, scale, add, flatten, and rebuild parameter pytrees.
# - Apply SGD updates to matching parameter and gradient structures.
#
# ## Mental Model
# A pytree is the structure plus its array leaves. JAX transformations preserve and reason about both pieces.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_08_pytrees as lesson
import solutions.lesson_08_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
params = lesson.make_two_layer_params(3, 4, 2)
leaves, treedef = lesson.flatten_tree(params)
rebuilt = lesson.unflatten_tree(treedef, leaves)
print('leaf_count=', len(leaves), 'l2_norm=', round(float(lesson.tree_l2_norm(params)), 4))
print('round_trip_keys=', sorted(rebuilt.keys()))
print('parameter_count=', int(solution.count_parameters(params)))
# Out:
# leaf_count= 4 l2_norm= 4.4721
# round_trip_keys= ['layer1', 'layer2']
# parameter_count= 26

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_count_parameters`. Count the total scalar parameters across every array leaf in a pytree.
#
# Hint: Use `jax.tree_util.tree_leaves` and sum each leaf's `.size`.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_count_parameters')
print('reference:', 'solutions.lesson_08_solution.count_parameters')
print('status: ready for student implementation')
# Out:
# exercise: exercise_count_parameters
# reference: solutions.lesson_08_solution.count_parameters
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Tree arithmetic preserves the nested parameter structure.
# - Flattening plus unflattening round-trips the original tree.
# - Parameter counts equal the sum of every leaf size.

# %% [markdown]
# ## Common Mistakes
# - Updating only one leaf while forgetting the rest of the tree.
# - Flattening a tree and losing the treedef needed to rebuild it.
#
# ## Extension
# Add a bias-only subtree and verify that the counting function does not assume layer names.
