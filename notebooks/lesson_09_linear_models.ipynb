# %% [markdown]
# # Lesson 09: Linear Models from Scratch
#
#             **Phase:** Training Foundations
#             **Script:** `lessons/lesson_09_linear_models.py`
#             **Exercise:** `exercise_mae_loss`
#             **Reference solution:** `solutions.lesson_09_solution.mae_loss`

# %% [markdown]
# ## What This Lesson Teaches
# - Build a deterministic linear regression dataset.
# - Train a linear model with explicit parameters and gradients.
# - Compare MSE and MAE as scalar training objectives.
#
# ## Mental Model
# A model can be just a pure function plus an explicit parameter pytree. Frameworks add ergonomics, not magic.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_09_linear_models as lesson
import solutions.lesson_09_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
x, y = lesson.make_regression_data()
params, losses = lesson.train_linear_model(num_steps=30, lr=0.1)
mae = solution.mae_loss(params, x, y)
print('loss_start_end=', (round(float(losses[0]), 4), round(float(losses[-1]), 4)))
print('prediction_shape=', lesson.linear_forward(params, x).shape, 'mae=', round(float(mae), 4))
# Out:
# loss_start_end= (21.0, 0.0)
# prediction_shape= (4, 1) mae= 0.0041

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_mae_loss`. Implement MAE loss for the linear model predictions.
#
# Hint: Take `jnp.mean(jnp.abs(linear_forward(params, x) - y))`.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_mae_loss')
print('reference:', 'solutions.lesson_09_solution.mae_loss')
print('status: ready for student implementation')
# Out:
# exercise: exercise_mae_loss
# reference: solutions.lesson_09_solution.mae_loss
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Training loss decreases over repeated gradient steps.
# - Learned parameters produce predictions with the target shape.
# - MAE is non-negative and shares the batch axis with MSE examples.

# %% [markdown]
# ## Common Mistakes
# - Mixing data generation, model evaluation, and optimization into one opaque function.
# - Changing loss definitions without checking their gradient behavior.
#
# ## Extension
# Swap the optimizer from plain gradient descent to momentum after lesson 10.
