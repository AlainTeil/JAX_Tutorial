# %% [markdown]
# # Lesson 10: Optimization Basics
#
#             **Phase:** Training Foundations
#             **Script:** `lessons/lesson_10_optimization.py`
#             **Exercise:** `exercise_adaptive_lr`
#             **Reference solution:** `solutions.lesson_10_solution.adaptive_lr`

# %% [markdown]
# ## What This Lesson Teaches
# - Minimize a convex quadratic with gradient descent.
# - Track optimizer state for momentum updates.
# - Schedule learning rates as explicit functions of step number.
#
# ## Mental Model
# Optimizers are state machines over parameters and auxiliary state. Keeping both explicit makes them easy to test and replace.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_10_optimization as lesson
import solutions.lesson_10_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
_, gd_losses = lesson.run_gd(num_steps=8, lr=0.1)
_, mom_losses = lesson.run_momentum(num_steps=8, lr=0.1, beta=0.9)
lr0 = solution.adaptive_lr(0, 0.1)
lr10 = solution.adaptive_lr(10, 0.1)
print('gd_last=', round(float(gd_losses[-1]), 4), 'momentum_last=', round(float(mom_losses[-1]), 4))
print('adaptive_lr=', (round(float(lr0), 4), round(float(lr10), 4)))
# Out:
# gd_last= 8.4882 momentum_last= 64.6898
# adaptive_lr= (0.1, 0.05)

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_adaptive_lr`. Implement a simple adaptive learning-rate schedule.
#
# Hint: Return a decayed version of `base_lr` as `step` increases.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_adaptive_lr')
print('reference:', 'solutions.lesson_10_solution.adaptive_lr')
print('status: ready for student implementation')
# Out:
# exercise: exercise_adaptive_lr
# reference: solutions.lesson_10_solution.adaptive_lr
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Gradient descent and momentum both move the parameter toward the quadratic minimum.
# - Momentum carries velocity between steps.
# - The adaptive learning rate remains positive and decreases over time.

# %% [markdown]
# ## Common Mistakes
# - Treating momentum velocity as hidden mutable state.
# - Judging an optimizer without plotting or inspecting the loss trajectory.
#
# ## Extension
# Try a too-large learning rate and inspect whether momentum helps or hurts.
