# %% [markdown]
# # Lesson 11: Mini-Batching and Data Pipelines
#
#             **Phase:** Training Foundations
#             **Script:** `lessons/lesson_11_minibatching.py`
#             **Exercise:** `exercise_epoch_mean_loss`
#             **Reference solution:** `solutions.lesson_11_solution.epoch_mean_loss`

# %% [markdown]
# ## What This Lesson Teaches
# - Create deterministic toy classification data.
# - Slice and shuffle mini-batches with explicit keys and indices.
# - Aggregate per-batch losses into epoch-level metrics.
#
# ## Mental Model
# Mini-batching is bookkeeping around arrays. Make indices, shuffling, and aggregation explicit so training remains reproducible.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_11_minibatching as lesson
import solutions.lesson_11_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
key = jax.random.key(0)
x, y = lesson.make_classification_data(12)
xb, yb = lesson.get_batch(x, y, 0, 4)
shuffled_x, shuffled_y = lesson.shuffle_data(key, x, y)
mean_loss = solution.epoch_mean_loss(jnp.array([0.9, 0.6, 0.3]))
print('batch_shape=', xb.shape, yb.shape, 'indices=', lesson.batch_indices(12, 5))
print('shuffle_preserves_shape=', shuffled_x.shape == x.shape and shuffled_y.shape == y.shape)
print('epoch_mean_loss=', round(float(mean_loss), 4))
# Out:
# batch_shape= (4, 2) (4,) indices= [(0, 5), (5, 10), (10, 12)]
# shuffle_preserves_shape= True
# epoch_mean_loss= 0.6

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_epoch_mean_loss`. Compute the mean loss across all batches in an epoch.
#
# Hint: Convert the sequence to a JAX array and call `jnp.mean`.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_epoch_mean_loss')
print('reference:', 'solutions.lesson_11_solution.epoch_mean_loss')
print('status: ready for student implementation')
# Out:
# exercise: exercise_epoch_mean_loss
# reference: solutions.lesson_11_solution.epoch_mean_loss
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Batch indices cover the dataset in predictable chunks.
# - Shuffled features and labels stay aligned.
# - Epoch mean loss is a scalar summary of batch losses.

# %% [markdown]
# ## Common Mistakes
# - Dropping or duplicating examples when the final batch is smaller.
# - Shuffling inputs and labels with different permutations.
#
# ## Extension
# Add a `drop_last` option and test how it changes the number of batches.
