# %% [markdown]
# # Lesson 12: Loss Functions and Numerical Stability
#
#             **Phase:** Training Foundations
#             **Script:** `lessons/lesson_12_losses_stability.py`
#             **Exercise:** `exercise_label_smoothing`
#             **Reference solution:** `solutions.lesson_12_solution.label_smoothing`

# %% [markdown]
# ## What This Lesson Teaches
# - Identify unstable probability-space loss calculations.
# - Use logits-space cross entropy and stable softmax patterns.
# - Apply label smoothing without changing batch or class axes.
#
# ## Mental Model
# Stable losses avoid forming extreme probabilities too early. Prefer logits and log-sum-exp based primitives when possible.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_12_losses_stability as lesson
import solutions.lesson_12_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
logits = jnp.array([[1000.0, 1001.0, 999.0]], dtype=jnp.float32)
labels = jnp.array([1], dtype=jnp.int32)
one_hot = jax.nn.one_hot(labels, 3)
smooth = solution.label_smoothing(one_hot, epsilon=0.1)
print('stable_softmax=', lesson.stable_softmax(logits).round(4).tolist())
print('cross_entropy=', round(float(lesson.cross_entropy_with_logits(logits, labels)), 4))
print('smoothed_row_sum=', float(jnp.sum(smooth)))
# Out:
# stable_softmax= [[0.24469999969005585, 0.6651999950408936, 0.08999999612569809]]
# cross_entropy= 0.4076
# smoothed_row_sum= 1.0

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_label_smoothing`. Implement label smoothing for one-hot class targets.
#
# Hint: Blend each one-hot row with a uniform distribution over classes.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_label_smoothing')
print('reference:', 'solutions.lesson_12_solution.label_smoothing')
print('status: ready for student implementation')
# Out:
# exercise: exercise_label_smoothing
# reference: solutions.lesson_12_solution.label_smoothing
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Stable softmax remains finite for large logits.
# - Logits-space cross entropy returns finite scalar losses.
# - Smoothed label rows still sum to one.

# %% [markdown]
# ## Common Mistakes
# - Taking `log` of probabilities that may be exactly zero.
# - Smoothing labels in a way that changes each row's probability mass.
#
# ## Extension
# Compare gradients from probability-space and logits-space losses on extreme logits.
