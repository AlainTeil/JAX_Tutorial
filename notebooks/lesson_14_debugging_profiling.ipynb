# %% [markdown]
# # Lesson 14: Debugging and Profiling JAX Programs
#
#             **Phase:** Advanced Single-Device JAX
#             **Script:** `lessons/lesson_14_debugging_profiling.py`
#             **Exercise:** `exercise_count_nans`
#             **Reference solution:** `solutions.lesson_14_solution.count_nans`

# %% [markdown]
# ## What This Lesson Teaches
# - Inspect traced programs with JAXPR.
# - Time eager and jitted functions without trusting the first compile call.
# - Detect NaNs and validate gradients with finite differences.
#
# ## Mental Model
# Debugging JAX often means separating compile-time tracing from runtime execution. Inspect the staged program and synchronize before timing.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_14_debugging_profiling as lesson
import solutions.lesson_14_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
x = jnp.array([1.0, jnp.nan, 3.0, jnp.nan])
jaxpr = lesson.polynomial_jaxpr(jnp.ones((2,)))
print('has_nans=', bool(lesson.has_nans(x)), 'count=', int(solution.count_nans(x)))
print('jaxpr_contains=', str(jaxpr).splitlines()[0][:60])
print('finite_diff=', round(float(lesson.finite_difference_grad(2.0)), 4))
# Out:
# has_nans= True count= 2
# jaxpr_contains= { lambda ; a:f32[2]. let
# finite_diff= 12.0

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_count_nans`. Count NaN values in an array.
#
# Hint: Use `jnp.isnan(x)` and sum the boolean mask.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_count_nans')
print('reference:', 'solutions.lesson_14_solution.count_nans')
print('status: ready for student implementation')
# Out:
# exercise: exercise_count_nans
# reference: solutions.lesson_14_solution.count_nans
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - The JAXPR contains primitive operations rather than Python source lines.
# - NaN checks identify exactly the invalid entries.
# - Finite-difference gradients are close to autodiff for smooth scalar examples.

# %% [markdown]
# ## Common Mistakes
# - Timing a jitted function without accounting for asynchronous dispatch or compilation.
# - Looking for Python side effects instead of inspecting arrays and JAXPR.
#
# ## Extension
# Add `jax.debug.print` to a tiny jitted function and observe when it emits output.
