# %% [markdown]
# # Lesson 16: Training Loops with Flax and Optax
#
#             **Phase:** Neural Network Stack
#             **Script:** `lessons/lesson_16_flax_optax_training.py`
#             **Exercise:** `exercise_classification_accuracy`
#             **Reference solution:** `solutions.lesson_16_solution.classification_accuracy`

# %% [markdown]
# ## What This Lesson Teaches
# - Create a Flax `TrainState` with model params and an Optax optimizer.
# - Write a jitted train step that updates state functionally.
# - Track loss and accuracy for a tiny classifier.
#
# ## Mental Model
# Flax owns the model definition, Optax owns optimizer transformations, and `TrainState` carries the explicit mutable-looking state as immutable values.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_16_flax_optax_training as lesson
import solutions.lesson_16_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
state, losses, x, y = lesson.train_for_steps(num_steps=20, learning_rate=0.1)
logits = state.apply_fn({'params': state.params}, x)
acc = solution.classification_accuracy(logits, y)
print('loss_start_end=', (round(float(losses[0]), 4), round(float(losses[-1]), 4)))
print('accuracy=', round(float(acc), 4), 'state_step=', int(state.step))
# Out:
# loss_start_end= (0.7202, 0.043)
# accuracy= 1.0 state_step= 20

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_classification_accuracy`. Compute classification accuracy from logits and integer labels.
#
# Hint: Use `jnp.argmax(logits, axis=-1)` and average equality with labels.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_classification_accuracy')
print('reference:', 'solutions.lesson_16_solution.classification_accuracy')
print('status: ready for student implementation')
# Out:
# exercise: exercise_classification_accuracy
# reference: solutions.lesson_16_solution.classification_accuracy
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Training loss decreases on the toy dataset.
# - The state step increments as training progresses.
# - Accuracy is a scalar in the range [0, 1].

# %% [markdown]
# ## Common Mistakes
# - Forgetting to pass `apply_fn` and params through the loss function explicitly.
# - Updating parameters without carrying optimizer state forward.
#
# ## Extension
# Swap Adam for SGD and compare the first 20 losses.
