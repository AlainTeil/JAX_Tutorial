# %% [markdown]
# # Lesson 17: Regularization and Model Evaluation
#
#             **Phase:** Neural Network Stack
#             **Script:** `lessons/lesson_17_regularization_eval.py`
#             **Exercise:** `exercise_f1_score`
#             **Reference solution:** `solutions.lesson_17_solution.f1_score`

# %% [markdown]
# ## What This Lesson Teaches
# - Add L2 regularization to a binary classifier loss.
# - Compute accuracy, precision, and recall from logits.
# - Interpret F1 as a balance between precision and recall.
#
# ## Mental Model
# Evaluation metrics are array programs too. Make thresholds and reductions explicit so they can be tested and transformed.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_17_regularization_eval as lesson
import solutions.lesson_17_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
params = {'w': jnp.array([[1.0], [-1.0]]), 'b': jnp.array([0.0])}
x = jnp.array([[1.0, 0.0], [0.0, 1.0]], dtype=jnp.float32)
y = jnp.array([1.0, 0.0], dtype=jnp.float32)
logits = lesson.linear_logits(params, x)
precision, recall = lesson.precision_recall_from_logits(logits, y)
print('total_loss=', round(float(lesson.total_loss(params, x, y, weight_decay=0.1)), 4))
print('precision_recall_f1=', (round(float(precision), 4), round(float(recall), 4), round(float(solution.f1_score(precision, recall)), 4)))
# Out:
# total_loss= 0.5133
# precision_recall_f1= (1.0, 1.0, 1.0)

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_f1_score`. Compute F1 from precision and recall with zero-safe denominator handling.
#
# Hint: Use `2 * precision * recall / max(precision + recall, eps)`.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_f1_score')
print('reference:', 'solutions.lesson_17_solution.f1_score')
print('status: ready for student implementation')
# Out:
# exercise: exercise_f1_score
# reference: solutions.lesson_17_solution.f1_score
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Regularized loss is at least as large as the data loss when weight decay is positive.
# - Precision and recall are bounded scalar metrics.
# - F1 is zero-safe and bounded between 0 and 1.

# %% [markdown]
# ## Common Mistakes
# - Reporting accuracy alone on imbalanced classification examples.
# - Dividing by zero when no positive predictions or labels are present.
#
# ## Extension
# Sweep classification thresholds and compare precision/recall tradeoffs.
