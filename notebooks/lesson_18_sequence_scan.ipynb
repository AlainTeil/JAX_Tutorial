# %% [markdown]
# # Lesson 18: Sequence Models with lax.scan
#
#             **Phase:** Neural Network Stack
#             **Script:** `lessons/lesson_18_sequence_scan.py`
#             **Exercise:** `exercise_reverse_scan`
#             **Reference solution:** `solutions.lesson_18_solution.reverse_scan_suffix_sum`

# %% [markdown]
# ## What This Lesson Teaches
# - Represent recurrent state updates as scan bodies.
# - Run a simple RNN over a sequence with explicit carry state.
# - Compute sequence losses with shape checks.
#
# ## Mental Model
# A recurrent model is a scan: carry the hidden state, emit outputs, and keep sequence axes explicit.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_18_sequence_scan as lesson
import solutions.lesson_18_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
xs = jnp.array([1.0, 2.0, 3.0, 4.0], dtype=jnp.float32)
params = {'wh': jnp.array([[0.5]]), 'wx': jnp.array([[1.0]]), 'b': jnp.array([0.0])}
outputs = lesson.run_simple_rnn(params, jnp.array([0.0]), xs.reshape(-1, 1))
print('scan_sum=', lesson.cumulative_sum_scan(xs).tolist())
print('rnn_output_shape=', outputs.shape)
print('reverse_suffix=', solution.reverse_scan_suffix_sum(xs).tolist())
# Out:
# scan_sum= [1.0, 3.0, 6.0, 10.0]
# rnn_output_shape= (4, 1)
# reverse_suffix= [10.0, 9.0, 7.0, 4.0]

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_reverse_scan`. Compute reverse suffix sums with `lax.scan` running backward.
#
# Hint: Use `reverse=True` and emit the updated carry at each step.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_reverse_scan')
print('reference:', 'solutions.lesson_18_solution.reverse_scan_suffix_sum')
print('status: ready for student implementation')
# Out:
# exercise: exercise_reverse_scan
# reference: solutions.lesson_18_solution.reverse_scan_suffix_sum
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Scan cumulative sums match simple examples.
# - RNN outputs keep one output per time step.
# - Reverse scan results align with suffix-sum intuition.

# %% [markdown]
# ## Common Mistakes
# - Mixing batch and time axes without naming the convention.
# - Closing over mutable hidden state instead of carrying it through scan.
#
# ## Extension
# Add a batch axis and use `vmap` around the scanned sequence function.
