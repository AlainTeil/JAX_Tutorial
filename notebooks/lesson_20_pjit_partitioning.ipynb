# %% [markdown]
# # Lesson 20: Partitioning and pjit Concepts
#
#             **Phase:** Scaling and Systems
#             **Script:** `lessons/lesson_20_pjit_partitioning.py`
#             **Exercise:** `exercise_make_sharded_array`
#             **Reference solution:** `solutions.lesson_20_solution.make_sharded_array`

# %% [markdown]
# ## What This Lesson Teaches
# - Build a named device mesh for partitioning examples.
# - Attach replicated and first-dimension shardings to arrays.
# - Understand single-device partitioning as placement metadata rather than speedup.
#
# ## Mental Model
# Named sharding describes how logical array axes map to a device mesh. The same API can be demonstrated on one device, but partitioning is only visible with multiple devices.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_20_pjit_partitioning as lesson
import solutions.lesson_20_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
x = jnp.arange(6, dtype=jnp.float32).reshape(2, 3)
w = jnp.ones((3, 2), dtype=jnp.float32)
y = lesson.pjit_matmul(x, w)
placed = solution.make_sharded_array(x)
print('devices=', len(jax.devices()), 'matmul=', y.tolist())
print('sharding_type=', type(lesson.inspect_array_sharding(placed)).__name__)
# Out:
# devices= 1 matmul= [[3.0, 3.0], [12.0, 12.0]]
# sharding_type= NamedSharding

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_make_sharded_array`. Place an array on a named sharding and return the resulting JAX array.
#
# Hint: Create a mesh, choose `NamedSharding(mesh, P('data', None))`, then call `jax.device_put`.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_make_sharded_array')
print('reference:', 'solutions.lesson_20_solution.make_sharded_array')
print('status: ready for student implementation')
# Out:
# exercise: exercise_make_sharded_array
# reference: solutions.lesson_20_solution.make_sharded_array
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Matrix multiplication returns the same numerical result as ordinary `x @ w`.
# - Sharding inspection returns a real sharding object.
# - The notebook states whether the current run is single-device or multi-device.

# %% [markdown]
# ## Common Mistakes
# - Equating `NamedSharding` metadata with actual multi-device parallelism on one device.
# - Using mesh contexts mechanically without explaining which calls need them.
#
# ## Extension
# Try the same lesson with forced multiple CPU devices before importing JAX.
