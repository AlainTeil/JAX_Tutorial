# %% [markdown]
# # Lesson 21: Tensor Sharding with Named Axes
#
#             **Phase:** Scaling and Systems
#             **Script:** `lessons/lesson_21_tensor_sharding.py`
#             **Exercise:** `exercise_verify_sharding_name`
#             **Reference solution:** `solutions.lesson_21_solution.verify_named_sharding`

# %% [markdown]
# ## What This Lesson Teaches
# - Place arrays with replicated and data-axis shardings.
# - Inspect sharding metadata after device placement.
# - Run linear algebra while preserving placement semantics.
#
# ## Mental Model
# Sharding is part of an array's placement contract. Correct code should make the intended axis names visible and testable.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_21_tensor_sharding as lesson
import solutions.lesson_21_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
x = jnp.arange(6, dtype=jnp.float32).reshape(2, 3)
placed = lesson.place_sharded_batch(x)
ok = solution.verify_named_sharding(placed)
print('devices=', len(jax.devices()), 'placed_shape=', placed.shape)
print('sharding=', type(placed.sharding).__name__, 'has_data_axis=', bool(ok))
# Out:
# devices= 1 placed_shape= (2, 3)
# sharding= NamedSharding has_data_axis= True

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_verify_sharding_name`. Verify that an array's sharding contains the expected named mesh axis.
#
# Hint: Inspect `x.sharding` and look for the axis name in its spec or string representation.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_verify_sharding_name')
print('reference:', 'solutions.lesson_21_solution.verify_named_sharding')
print('status: ready for student implementation')
# Out:
# exercise: exercise_verify_sharding_name
# reference: solutions.lesson_21_solution.verify_named_sharding
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Placed arrays report sharding metadata.
# - Single-device examples still preserve named-axis intent.
# - The verification exercise returns a boolean-style result.

# %% [markdown]
# ## Common Mistakes
# - Assuming sharding is visible from array values alone.
# - Forgetting to verify axis names when teaching partitioned tensor layouts.
#
# ## Extension
# Extend the mesh to include a model axis on hardware that supports it.
