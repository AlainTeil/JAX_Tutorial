# %% [markdown]
# # Lesson 22: Checkpointing and Experiment Management
#
#             **Phase:** Production Workflow
#             **Script:** `lessons/lesson_22_checkpointing_experiments.py`
#             **Exercise:** `exercise_best_run`
#             **Reference solution:** `solutions.lesson_22_solution.best_run`

# %% [markdown]
# ## What This Lesson Teaches
# - Record run metadata in plain serializable structures.
# - Save and restore small parameter pytrees.
# - Keep notebook-generated artifacts out of tracked repository files.
#
# ## Mental Model
# Experiment state is useful only when it can be restored and compared. Keep metadata explicit and write demos to temporary paths.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_22_checkpointing_experiments as lesson
import solutions.lesson_22_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
from tempfile import TemporaryDirectory
with TemporaryDirectory() as tmp:
    path = Path(tmp) / 'demo_meta.json'
    meta = lesson.make_run_metadata('demo-run', seed=0, learning_rate=0.1, num_steps=100)
    lesson.save_run_metadata(path, meta)
    restored = lesson.load_run_metadata(path)
runs = [{'name': 'a', 'validation_loss': 0.4}, {'name': 'b', 'validation_loss': 0.2}]
print('metadata_name=', restored['run_name'], 'steps=', restored['num_steps'])
print('best_run=', solution.best_run(runs)['name'])
# Out:
# metadata_name= demo-run steps= 100
# best_run= b

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_best_run`. Select the best run metadata entry by validation loss.
#
# Hint: Use `min(runs, key=lambda run: run['validation_loss'])` or an equivalent explicit comparison.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_best_run')
print('reference:', 'solutions.lesson_22_solution.best_run')
print('status: ready for student implementation')
# Out:
# exercise: exercise_best_run
# reference: solutions.lesson_22_solution.best_run
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Metadata round-trips through JSON without changing fields.
# - Checkpointed parameter leaves restore with matching values.
# - Notebook execution writes only to a temporary directory.

# %% [markdown]
# ## Common Mistakes
# - Writing notebook demo outputs over tracked files.
# - Saving parameters without enough metadata to reproduce the run.
#
# ## Extension
# Add git commit hash or dependency versions to the metadata dictionary.
