# %% [markdown]
# # Lesson 23: JAX Ecosystem Tour
#
#             **Phase:** Production Workflow
#             **Script:** `lessons/lesson_23_jax_ecosystem.py`
#             **Exercise:** `exercise_is_loss_decreasing`
#             **Reference solution:** `solutions.lesson_23_solution.is_loss_decreasing`

# %% [markdown]
# ## What This Lesson Teaches
# - Identify where core JAX ends and ecosystem libraries begin.
# - Run one Optax optimizer update by hand.
# - Use trend checks to validate training logs.
#
# ## Mental Model
# JAX is the transformation and array substrate; libraries such as Flax and Optax package common modeling and optimization patterns on top.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_23_jax_ecosystem as lesson
import solutions.lesson_23_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
summary = lesson.ecosystem_summary()
params, new_params = lesson.demo_optax_adam_update()
losses = jnp.array([1.0, 0.8, 0.5], dtype=jnp.float32)
print('libraries=', sorted(summary.keys()))
print('params_changed=', bool(jnp.any(params['w'] != new_params['w'])))
print('loss_decreasing=', bool(solution.is_loss_decreasing(losses)))
# Out:
# libraries= ['chex', 'equinox', 'flax', 'jax', 'optax', 'orbax']
# params_changed= True
# loss_decreasing= True

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_is_loss_decreasing`. Return whether a sequence of losses is decreasing from first to last.
#
# Hint: Compare the last loss to the first loss and return a boolean scalar/value.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_is_loss_decreasing')
print('reference:', 'solutions.lesson_23_solution.is_loss_decreasing')
print('status: ready for student implementation')
# Out:
# exercise: exercise_is_loss_decreasing
# reference: solutions.lesson_23_solution.is_loss_decreasing
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - The ecosystem summary names the role of each library.
# - An Optax update changes parameters and optimizer state.
# - Loss trend checks catch non-improving runs.

# %% [markdown]
# ## Common Mistakes
# - Treating ecosystem libraries as replacements for understanding JAX transformations.
# - Checking only the final loss without validating the trajectory direction.
#
# ## Extension
# Add a short note about a library you would use for data loading, serving, or checkpointing.
