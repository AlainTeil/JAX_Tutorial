# %% [markdown]
# # Lesson 28: Multi-Device Readiness Checks
#
#             **Phase:** Integration Labs
#             **Script:** `lessons/lesson_28_multidevice_readiness.py`
#             **Exercise:** `exercise_validate_global_batch_size`
#             **Reference solution:** `solutions.lesson_28_solution.validate_global_batch_size`

# %% [markdown]
# ## What This Lesson Teaches
# - Report device inventory before selecting a parallel execution strategy.
# - Validate global batch sizes for per-device splitting.
# - Label single-device fallback behavior separately from collective execution.
#
# ## Mental Model
# Production multi-device code starts with readiness checks: device count, global batch divisibility, and explicit fallback behavior.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_28_multidevice_readiness as lesson
import solutions.lesson_28_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
info = lesson.device_inventory()
x = jnp.arange(8, dtype=jnp.float32).reshape(4, 2)
reshaped = lesson.reshape_global_batch(x, num_devices=1)
valid = solution.validate_global_batch_size(batch_size=8, num_devices=2)
invalid = solution.validate_global_batch_size(batch_size=7, num_devices=2)
print('inventory=', info['backend'], info['local_device_count'], lesson.collective_mode_label())
print('reshaped_shape=', reshaped.shape)
print('valid_invalid=', bool(valid), bool(invalid))
# Out:
# inventory= cpu 1 single-device fallback path
# reshaped_shape= (1, 4, 2)
# valid_invalid= True False

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_validate_global_batch_size`. Return whether a global batch size can be split evenly across the selected devices.
#
# Hint: Require a positive device count, at least one example per device, and exact divisibility.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_validate_global_batch_size')
print('reference:', 'solutions.lesson_28_solution.validate_global_batch_size')
print('status: ready for student implementation')
# Out:
# exercise: exercise_validate_global_batch_size
# reference: solutions.lesson_28_solution.validate_global_batch_size
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Device inventory reports backend and local device count.
# - Reshaped global batches expose a device-major leading axis.
# - Invalid batch/device combinations are rejected before parallel code runs.

# %% [markdown]
# ## Common Mistakes
# - Assuming a notebook is using collectives just because it imports `pmap` concepts.
# - Choosing a global batch size that cannot be split evenly across devices.
#
# ## Extension
# Run the lesson in a fresh process with simulated CPU devices and compare the readiness report.
