# %% [markdown]
# # Lesson 29: Experiment Analysis and Comparison
#
#             **Phase:** Integration Labs
#             **Script:** `lessons/lesson_29_experiment_analysis.py`
#             **Exercise:** `exercise_select_pareto_runs`
#             **Reference solution:** `solutions.lesson_29_solution.select_pareto_runs`

# %% [markdown]
# ## What This Lesson Teaches
# - Rank experiment runs by validation loss and runtime.
# - Attach environment metadata to make comparisons reproducible.
# - Identify Pareto-efficient runs when accuracy and cost trade off.
#
# ## Mental Model
# Experiment analysis turns run metadata into decisions. Keep metrics and costs explicit so ranking rules can be reviewed.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_29_experiment_analysis as lesson
import solutions.lesson_29_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
runs = lesson.make_demo_runs()
ranked = lesson.rank_runs(runs)
summary = lesson.summarize_runs(runs)
enriched = lesson.attach_environment({'run_name': 'demo'}, {'jax': jax.__version__})
pareto = solution.select_pareto_runs(runs)
print('best=', ranked[0]['run_name'], 'summary_best=', summary['best_run_name'])
print('packages=', enriched['packages'])
print('pareto=', [run['run_name'] for run in pareto])
# Out:
# best= wider summary_best= wider
# packages= {'jax': '0.9.2'}
# pareto= ['wider', 'fast']

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_select_pareto_runs`. Select runs that are not dominated on both validation loss and runtime.
#
# Hint: A run is dominated if another run is no worse on both metrics and strictly better on at least one.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_select_pareto_runs')
print('reference:', 'solutions.lesson_29_solution.select_pareto_runs')
print('status: ready for student implementation')
# Out:
# exercise: exercise_select_pareto_runs
# reference: solutions.lesson_29_solution.select_pareto_runs
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - The best run by validation loss is easy to identify from ranked metadata.
# - Environment fields are copied into the run summary without changing metric values.
# - Pareto selection keeps only runs that preserve a useful loss/runtime tradeoff.

# %% [markdown]
# ## Common Mistakes
# - Choosing the lowest loss without checking whether the runtime cost is acceptable.
# - Comparing runs without recording package or environment context.
#
# ## Extension
# Add confidence intervals or repeated-seed aggregation to the run comparison.
