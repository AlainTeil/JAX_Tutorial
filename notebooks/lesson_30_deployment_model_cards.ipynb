# %% [markdown]
# # Lesson 30: Deployment Checks and Model Cards
#
#             **Phase:** Integration Labs
#             **Script:** `lessons/lesson_30_deployment_model_cards.py`
#             **Exercise:** `exercise_apply_threshold`
#             **Reference solution:** `solutions.lesson_30_solution.apply_threshold`

# %% [markdown]
# ## What This Lesson Teaches
# - Convert model scores into reviewable prediction records.
# - Summarize calibration bins for simple deployment checks.
# - Package metrics and limitations into a lightweight model card.
#
# ## Mental Model
# Deployment is another transformation boundary: numeric outputs become decisions, reports, and operational constraints.

# %%
from pathlib import Path

import jax
import jax.numpy as jnp

import lessons.lesson_30_deployment_model_cards as lesson
import solutions.lesson_30_solution as solution

# %% [markdown]
# ## Guided Demo
# Run the cell below before attempting the exercise. It prints compact evidence for the key shapes, values, or state transitions.

# %%
logits = jnp.array([-2.0, -0.2, 0.4, 2.0], dtype=jnp.float32)
probs = lesson.sigmoid_scores(logits)
labels = jnp.array([0, 0, 1, 1], dtype=jnp.int32)
table = lesson.prediction_table(['a', 'b', 'c', 'd'], probs, threshold=0.5)
bins = lesson.calibration_bins(probs, labels, num_bins=2)
card = lesson.model_card('toy classifier', {'accuracy': 1.0}, ['toy data only'])
preds = solution.apply_threshold(probs, threshold=0.5)
print('preds=', preds.tolist(), 'table_rows=', len(table))
print('bins=', bins)
print('card_keys=', sorted(card.keys()))
# Out:
# preds= [0, 0, 1, 1] table_rows= 4
# bins= [{'bin': 0, 'count': 2, 'confidence': 0.2846844792366028, 'accuracy': 1.0}, {'bin': 1, 'count': 2, 'confidence': 0.7397423386573792, 'accuracy': 1.0}]
# card_keys= ['limitations', 'metrics', 'summary']

# %% [markdown]
# ## Workbook Exercise
# TODO: `exercise_apply_threshold`. Convert probabilities into integer predictions using a configurable threshold.
#
# Hint: Compare probabilities with the threshold and cast the boolean mask to integer labels.
#
# The next cell prints the exercise name, reference solution path, and ready status so this published notebook stays executable. Replace it with your own scratch implementation while studying.

# %%
print('exercise:', 'exercise_apply_threshold')
print('reference:', 'solutions.lesson_30_solution.apply_threshold')
print('status: ready for student implementation')
# Out:
# exercise: exercise_apply_threshold
# reference: solutions.lesson_30_solution.apply_threshold
# status: ready for student implementation

# %% [markdown]
# ## Expected Output Checkpoint
# - Prediction tables preserve IDs, scores, and thresholded decisions.
# - Calibration bins report counts, confidence, and accuracy per range.
# - Model cards contain metrics and limitations in serializable fields.

# %% [markdown]
# ## Common Mistakes
# - Shipping a threshold without documenting how it changes precision and recall.
# - Reporting metrics without limitations or intended-use context.
#
# ## Extension
# Evaluate two thresholds and describe which deployment risk each threshold changes.
